# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %run /Users/muon02/lgca-feedback/lgca-feedback/no_img/output/sim002.py

# %%
alpha = [0,1,2,3,4]

# %%
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False

plt.figure(figsize=(24, 12), dpi=200)

fig,ax = plt.subplots()

plt.errorbar(alpha, mean_front_95, yerr=sd_front_95, fmt='-', color='blue', label=r'$q_{95}$')
plt.errorbar(alpha, mean_front_Naive, yerr=sd_front_Naive, fmt='-', color='red', label=r'Naive measure')
plt.errorbar(alpha, mean_front_zeros, yerr=sd_front_zeros, fmt='-', color='green', label=r'First zero')
plt.xticks(alpha)
ax.set(xlabel=r'Feedback strength ($\alpha$)', ylabel='Front position ($F$)',
       title='Motilities')
plt.grid(axis='y')
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=(24, 12), dpi=80)

fig, ax = plt.subplots()

plt.errorbar(alpha, mean_dom_mode_95, yerr=sd_dom_mode_95, fmt='-', color='orange', label=r'q_{95}')

plt.errorbar(alpha, mean_dom_mode_zeros, yerr=sd_dom_mode_zeros, fmt='-', color='purple',label=r'Zeros')
plt.xticks(alpha)

ax.set(xlabel=r'Feedback strength ($\alpha$)', ylabel='Dominant mode',
       title='Front Inestability')
plt.grid(axis='y')
plt.legend(loc='best')

plt.show()

# %%
plt.figure(figsize=(24, 12), dpi=80)

fig, ax = plt.subplots()

plt.errorbar(alpha, mean_leght_poly_95, yerr=sd_dom_mode_95, fmt='-', color='green')

plt.xticks(alpha)

ax.set(xlabel=r'Feedback strength ($\alpha$)', ylabel='Lenght of polygonal',
       title=r'Front Inestability $q_{95}$')
plt.grid(axis='y')

plt.show()
