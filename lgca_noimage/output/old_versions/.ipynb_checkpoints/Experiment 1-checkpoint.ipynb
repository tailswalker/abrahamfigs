# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %run /Users/muon02/lgca-feedback/lgca-feedback/no_img/output/sim001.py

# %%
VecbS = [4,8,12,16,20,24]

# %%
plt.figure(figsize=(24, 12), dpi=80)

fig,ax = plt.subplots()

plt.errorbar(VecbS, mean_front_95, yerr=sd_front_95, fmt='-', color='blue')
plt.errorbar(VecbS, mean_front_Naive, yerr=sd_front_Naive, fmt='-', color='red')
plt.errorbar(VecbS, mean_front_zeros, yerr=sd_front_zeros, fmt='-', color='green')
plt.xticks(VecbS)
ax.set(xlabel=r'Number of channels ($b_{S}=b_{T}$)', ylabel='Front position ($F$)',
       title='Motilities')
plt.show()

# %%
plt.figure(figsize=(24, 12), dpi=80)

fig,ax = plt.subplots()

plt.errorbar(VecbS, mean_front_95, yerr=sd_front_95, fmt='-', color='green')
plt.errorbar(VecbS, mean_front_95CSC, yerr=sd_front_95CSC, fmt='-', color='blue')
plt.errorbar(VecbS, mean_front_95TD, yerr=sd_front_95TD, fmt='-', color='red')
plt.xticks(VecbS)
ax.set(xlabel=r'Number of channels ($b_{S}=b_{T}$)', ylabel='Front position ($F$)',
       title='Motilities front 95')
plt.show()

# %%
print(mean_front_95)
print(mean_front_95CSC)
# Out:
# [148.144, 83.5717, 56.9103, 41.9713, 32.3353, 25.5357]
# [148.18, 84.267, 57.3763, 42.2297, 32.4277, 25.4013]

# %%
plt.figure(figsize=(24, 12), dpi=80)

fig,ax = plt.subplots()

plt.errorbar(VecbS, mean_front_Naive, yerr=sd_front_Naive, fmt='-', color='green')
plt.errorbar(VecbS, mean_front_NaiveCSC, yerr=sd_front_NaiveCSC, fmt='-', color='blue')
plt.errorbar(VecbS, mean_front_NaiveTD, yerr=sd_front_NaiveTD, fmt='-', color='red')
plt.xticks(VecbS)
ax.set(xlabel=r'Number of channels ($b_{S}=b_{T}$)', ylabel='Front position ($F$)',
       title='Motilities front Naive')
plt.show()

# %%
plt.figure(figsize=(24, 12), dpi=80)

fig,ax = plt.subplots()

plt.errorbar(VecbS, mean_front_zeros, yerr=sd_front_zeros, fmt='-', color='green')
plt.errorbar(VecbS, mean_front_zerosCSC, yerr=sd_front_zerosCSC, fmt='-', color='blue')
plt.errorbar(VecbS, mean_front_zerosTD, yerr=sd_front_zerosTD, fmt='-', color='red')
plt.xticks(VecbS)
ax.set(xlabel=r'Number of channels ($b_{S}=b_{T}$)', ylabel='Front position ($F$)',
       title='Motilities front Zeros')
plt.show()

# %%
plt.figure(figsize=(24, 12), dpi=80)

fig,ax = plt.subplots(1,2)

plt.subplot(1,2,1)
plt.errorbar(VecbS, mean_dom_mode_95, yerr=sd_dom_mode_95, fmt='-', color='orange')
plt.xticks(VecbS)

plt.subplot(1,2,2)
plt.errorbar(VecbS, mean_dom_mode_zeros, yerr=sd_dom_mode_zeros, fmt='-', color='purple')
plt.xticks(VecbS)

plt.show()

# %%
plt.figure(figsize=(24, 12), dpi=80)

fig,ax = plt.subplots(1,2)

plt.subplot(1,2,1)
plt.errorbar(VecbS, mean_leght_poly_95, yerr=sd_leght_poly_95, fmt='-', color='orange')
plt.xticks(VecbS)

plt.subplot(1,2,2)
plt.errorbar(VecbS, mean_leght_poly_zeros, yerr=sd_leght_poly_zeros, fmt='-', color='purple')
plt.xticks(VecbS)

plt.show()

# %%
plt.figure(figsize=(24, 12), dpi=80)

fig,ax = plt.subplots()

plt.errorbar(VecbS, mean_leght_poly_95, yerr=sd_leght_poly_95, fmt='-', color='green')
plt.errorbar(VecbS, mean_leght_poly_95CSC, yerr=sd_leght_poly_95CSC, fmt='-', color='blue')
plt.errorbar(VecbS, mean_leght_poly_95TD, yerr=sd_leght_poly_95TD, fmt='-', color='red')
plt.xticks(VecbS)
ax.set(xlabel=r'Number of channels ($b_{S}=b_{T}$)', ylabel='Length of curve ($F$)',
       title='Motilities length of curve')
plt.show()
